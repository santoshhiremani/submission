# %% [markdown]
# # My Jupyer Notebook on IBM Watson Studio

# %% [markdown]
# **"Santosh Hiremani** "/n"
# Engineer

# %% [markdown]
# *I would like to learn about data science, because I work with large datasets in my job and doing so with the correct tools would save me time*

# %% [markdown]
# ### I do not know how to use Python so have only written a simple loop:

# %%
count=1
for i in range(1,3):
    count=i+i
print(count)
# Out:
# 4

# %% [markdown]
# Module 1 has ~~taught~~ shown me:
#   * Which codes are used for data science
#   * What cloud platforms are available
#   * Examples of data science uses
#
# https://github.com/
